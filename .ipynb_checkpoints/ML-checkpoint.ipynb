# %% [markdown]
# ### Objective of the Assignment:
# *The aim of this assignment is to generate value and insight from the processing of heterogeneous data. This will be achieved by implementing several analytic methods/techniques/algorithms, evaluating them and comparing the effectiveness of the adopted approaches.*
#
# ### Data Collection:
# *The Global Health Observatory (GHO) data repository under World Health Organization (WHO) keeps track of the health status as well as many other related factors for all countries The datasets are made available to public for the purpose of health data analysis.*

# %%
#Importing Libraries
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline
plt.style.use('seaborn-darkgrid')

# %%
df = pd.read_csv('Life Expectancy Data.csv')
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %% [markdown]
# *After a bit exploring we'll check if we have any null values in our data*

# %%
#Checking for null-values if any 
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df.shape
# Out:
# (2938, 22)

# %% [markdown]
# *We will drop the null value rows from our dataframe*

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (1649, 22)

# %%
#Checking for null-values if any 
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### Exploratory Data Analysis

# %%
#Checking for unique values 
df.nunique()
# Out:
# Country                             133
# Year                                 16
# Status                                2
# Life expectancy                     320
# Adult Mortality                     369
# infant deaths                       165
# Alcohol                             833
# percentage expenditure             1645
# Hepatitis B                          83
# Measles                             603
#  BMI                                538
# under-five deaths                   199
# Polio                                68
# Total expenditure                   669
# Diphtheria                           66
#  HIV/AIDS                           167
# GDP                                1649
# Population                         1647
#  thinness  1-19 years               179
#  thinness 5-9 years                 185
# Income composition of resources     548
# Schooling                           147
# dtype: int64

# %%
df['Status'].unique()
# Out:
# array(['Developing', 'Developed'], dtype=object)

# %%
#Identifying relationship between Country Status and Life Expectancy 
plt.figure(figsize=(8,8))
df.groupby(['Status'])['Life expectancy '].mean().plot(kind='bar', color='#087E8B')
# Out:
# <AxesSubplot:xlabel='Status'>

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Exploratory Visualization - (COUNTRY)

# %%
#Top 10 countries with life-expendancy.
plt.figure(figsize=(30,5))
val=df.groupby('Country')['Life expectancy '].mean()[:10].sort_values(ascending=False).plot(kind='bar',fontsize=20, color='#087E8B')

# %%
# Top 10 countries on adult morality
plt.figure(figsize=(20,5))
val=df.groupby('Country')['Adult Mortality'].mean()[:10].sort_values(ascending=False).plot(kind='bar',fontsize=15, color='#087E8B')

# %%
# Top 10 countries on adult morality
plt.figure(figsize=(20,5))
val=df.groupby('Country')[' HIV/AIDS'].mean()[:10].sort_values(ascending=False).plot(kind='bar',fontsize=15, color='#087E8B')

# %%
plt.figure(figsize=(30,5))
val=df.groupby('Country')['infant deaths'].mean()[:10].sort_values(ascending=False).plot(kind='bar',fontsize=20, color='#087E8B')

# %%
#Top 10 countries with the most alcoholic people.
plt.figure(figsize=(30,5))
val=df.groupby('Country')['Alcohol'].mean()[:10].sort_values(ascending=False).plot(kind='bar',fontsize=20,color='#087E8B')

# %%
#Top 10 countries with polio.
plt.figure(figsize=(30,5))
val=df.groupby('Country')['Polio'].mean()[:10].sort_values(ascending=False).plot(kind='bar',fontsize=20,color='#087E8B')

# %% [markdown]
# #### 2. Exploratory Visualization - (YEAR)

# %%
#Top 20 years with polio.
plt.figure(figsize=(30,5))
val=df.groupby('Year')['Polio'].mean()[:20].sort_values(ascending=False).plot(kind='bar',fontsize=20,color='#FFB6C1')

# %%
#Illustration of Infant deaths according to the years
plt.figure(figsize=(30,5))
val=df.groupby('Year')['infant deaths'].mean()[:20].sort_values(ascending=False).plot(kind='bar',fontsize=20,color='#FFB6C1')

# %%
plt.figure(figsize=(30,5))
val=df.groupby('Year')['Schooling'].mean()[:20].sort_values(ascending=False).plot(kind='bar',fontsize=20,color='#FFB6C1')

# %% [markdown]
# ### Feature Engineering
# *Feature engineering refers to the process of using domain knowledge to select and transform the most relevant variables from raw data when creating a predictive model using machine learning or statistical modeling*

# %%
df.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# ...

# %% [markdown]
# *We'll select the numerical columns in-order to predict regression based model*

# %%
numeric_lst=['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numerical_cols = list(df.select_dtypes(include=numeric_lst).columns)

# %%
numerical_cols
# Out:
# ['Year',
#  'Life expectancy ',
#  'Adult Mortality',
#  'infant deaths',
#  'Alcohol',
#  'percentage expenditure',
#  'Hepatitis B',
#  'Measles ',
#  ' BMI ',
#  'under-five deaths ',
#  'Polio',
#  'Total expenditure',
#  'Diphtheria ',
#  ' HIV/AIDS',
#  'GDP',
#  'Population',
#  ' thinness  1-19 years',
#  ' thinness 5-9 years',
#  'Income composition of resources',
#  'Schooling']

# %%
data = df[numerical_cols]

# %%
data.dtypes
# Out:
# Year                                 int64
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# dtype: object

# %%
data.head()
# Out:
#    Year  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0  2015              65.0            263.0             62     0.01
# 1  2014              59.9            271.0             64     0.01
# 2  2013              59.9            268.0             66     0.01
# 3  2012              59.5            272.0             69     0.01
# 4  2011              59.2            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   under-five deaths   \
# 0               71.279624         65.0      1154   19.1                  83
# 1               73.523582         62.0       492   18.6                  86
# 2               73.219243         64.0       430   18.1                  89
# 3               78.184215         67.0      2787   17.6                  93
# 4                7.097109         68.0      3013   17.2                  97
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(data.drop(labels=['Life expectancy '], axis=1),data['Life expectancy '],test_size=0.3,random_state=0)

# %%
X_train.isnull().sum()
# Out:
# Year                               0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
from sklearn.feature_selection import mutual_info_regression
# determine the mutual information
mutual_info = mutual_info_regression(X_train, y_train)
mutual_info
# Out:
# array([0.08401649, 1.21860862, 0.40705714, 0.41272838, 0.32936268,
#        0.17667875, 0.1057058 , 0.63646619, 0.42026018, 0.21795937,
#        0.33257677, 0.1828032 , 0.47600991, 0.37297221, 0.12223362,
#        0.78847544, 0.77828319, 0.8984281 , 0.63325335])

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = X_train.columns
mutual_info.sort_values(ascending=False)
# Out:
# Adult Mortality                    1.218609
# Income composition of resources    0.898428
#  thinness  1-19 years              0.788475
#  thinness 5-9 years                0.778283
#  BMI                               0.636466
# Schooling                          0.633253
#  HIV/AIDS                          0.476010
# under-five deaths                  0.420260
# Alcohol                            0.412728
# infant deaths                      0.407057
# GDP                                0.372972
# Total expenditure                  0.332577
# percentage expenditure             0.329363
# Polio                              0.217959
# Diphtheria                         0.182803
# Hepatitis B                        0.176679
# Population                         0.122234
# Measles                            0.105706
# Year                               0.084016
# dtype: float64

# %%
mutual_info.sort_values(ascending=False).plot.bar(figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
from sklearn.feature_selection import SelectKBest

# %% [markdown]
# ##### After the feature engineering, we'll use the best 5 features to predict the Life Expectancy

# %%
sel_five_cols = SelectKBest(mutual_info_regression, k=5)
z= sel_five_cols.fit(X_train, y_train)
imp_cols = X_train.columns[z.get_support()]

# %%
X_train=X_train[list(imp_cols)]

# %% [markdown]
# ### Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
lr_model=LinearRegression()

# %%
lr_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test=X_test[list(imp_cols)]

# %%
predictions=lr_model.predict(X_test)

# %%
predictions
# Out:
# array([60.57315604, 74.86602892, 70.60597443, 55.00113071, 64.99974722,
#        81.49486959, 53.84630824, 66.97409277, 49.7340135 , 74.16544303,
#        79.0454714 , 73.35793882, 78.58943982, 71.84120069, 81.14351703,
#        68.76037457, 69.07880933, 70.59516582, 71.42012476, 69.59552748,
#        79.98885844, 68.91139099, 63.10348152, 71.91337334, 71.61135536,
#        58.24326095, 64.17820853, 69.1928869 , 78.83224365, 68.3498569 ,
#        69.33778368, 52.09745327, 59.52737342, 71.79927093, 73.98796211,
#        70.36611703, 70.35420252, 79.17105287, 80.7757564 , 49.35728803,
#        78.66850159, 64.11893928, 78.56233299, 76.21866409, 80.88953015,
#        75.30997971, 55.08144565, 69.53204213, 71.98389341, 78.48754902,
#        61.33449797, 67.09693506, 57.39655155, 77.92192871, 66.73966642,
#        79.08026201, 73.8716237 , 73.29920705, 69.84092484, 67.47862239,
#        71.36225734, 67.48946102, 65.92736616, 75.21396624, 76.11753647,
# ...

# %%
print('This is regration accuracy score:')
lr_model.score(X_test, y_test)
# Out:
# This is regration accuracy score:
# 0.7221475756661841

# %%
model1 = lr_model.score(X_test, y_test)

# %%
best_model = []
best_model.append(model1)

# %%
prediction_of_test = lr_model.predict(X_test)
plt.scatter(y_test, prediction_of_test, color='black')

x0 = min(y_test)
x1 = max(y_test)
y0 = min(prediction_of_test)
y1 = max(prediction_of_test)
plt.plot([x0,x1],[y0,y1],color="red")

plt.xlabel("Input Data")
plt.ylabel("Life Expectancy")
plt.title("Input Data Vs Life Expectancy")

print('Linear Regration of Input Data vs Life Expectancy:')
print('')
plt.show()
# Out:
# Linear Regration of Input Data vs Life Expectancy:

# %% [markdown]
# *Thus by looking at the graph, we can see that there are outliers in our data, if we want to make the predictions more precise we can elimate these outliers and then re-train the model to get more accurate predictions*

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
rfr_model=RandomForestRegressor()

# %%
rfr_model.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
preds=rfr_model.predict(X_test)

# %%
preds
# Out:
# array([57.845, 80.484, 75.719, 55.153, 62.786, 81.275, 55.359, 53.034,
#        46.457, 72.974, 80.878, 74.043, 80.954, 73.163, 80.249, 53.669,
#        54.324, 73.394, 73.875, 67.752, 78.676, 67.636, 66.389, 73.8  ,
#        73.789, 64.615, 66.117, 59.393, 82.334, 71.096, 71.837, 47.777,
#        57.882, 71.998, 72.897, 72.251, 73.188, 82.856, 79.475, 57.495,
#        76.425, 65.131, 80.083, 68.161, 82.442, 80.823, 52.203, 74.511,
#        72.805, 82.3  , 60.579, 70.668, 55.802, 79.499, 68.214, 83.008,
#        75.423, 78.187, 69.952, 68.628, 72.303, 73.523, 70.809, 76.566,
#        77.602, 82.678, 72.774, 71.679, 71.55 , 74.927, 67.808, 79.531,
#        45.487, 82.219, 80.645, 57.829, 76.547, 83.316, 65.335, 66.681,
#        59.653, 76.674, 71.083, 68.236, 62.354, 65.633, 73.106, 44.495,
#        64.41 , 65.997, 62.591, 75.739, 76.581, 47.195, 72.576, 61.433,
#        69.288, 58.695, 46.753, 53.11 , 47.032, 62.654, 75.225, 67.565,
# ...

# %%
rfr_model.score(X_test,y_test)
# Out:
# 0.9468859262537747

# %%
model2 = rfr_model.score(X_test,y_test)

# %%
best_model.append(model2)

# %%
print("The Model Accuracy for Linear Regression: ", best_model[0]*100, '%')
print("The Model Accuracy for Random Forest: ", best_model[1]*100, '%')
# Out:
# The Model Accuracy for Linear Regression:  72.21475756661842 %
# The Model Accuracy for Random Forest:  94.68859262537747 %
